# %% [markdown]
# ## List in python
# #### ordered mutable ,allows duplicate values

# %%
fruits=['apple',48,63.3,(4j+2),True]

# %%
print(fruits[0]) # accessing   # apple 
fruits.append('banana')
print(fruits)
fruits.pop(0)
print(fruits)
# Out:
# apple
# ['apple', 48, 63.3, (2+4j), True, 'banana']
# [48, 63.3, (2+4j), True, 'banana']

# %%
# Handson  TA aisha trainer

# %%
dict1 = {}
total_marks = 0
for i in range(5):
    s_name= input(f"Enter student {i} name")
    s_marks = int(input("Enter marks"))
    total_marks +=s_marks
    dict1[s_name]=s_marks

# %%
print(dict1)
average = total_marks/5
# Out:
# {'a': 95, 'b': 99, 'c': 96, 'd': 45, 'e': 56}

# %%
average
# Out:
# 78.2

# %%
for i in dict1:
    print(dict1[i])
# Out:
# 95
# 99
# 96
# 45
# 56

# %%
def print_result(name,marks):
    for i in dict1:
        if dict1[i]>50:
            print(f"{i} is pass")
        else:
            print(f"i is fail")

# %%
print_result(i,dict1[i])
# Out:
# a is pass
# b is pass
# c is pass
# i is fail
# e is pass

# %%
## BASIC BILLING SYSTEM

# %%
product_count = int(input("Ener how many products do you have"))
product_dict = {}
for i in range(product_count):
    P_name = input("Enter Product Name ")
    P_prize = int(input(f"Enter prize of {P_name}"))
    product_dict[P_name] = P_prize

# %%
def generate_bill(product_dict):
    total_bill = 0
    for i in product_dict:
        total_bill +=product_dict[i]
        print(i,product_dict[i])
    print(f"the total bill is",total_bill)

# %%
generate_bill(product_dict)
# Out:
# banana 30
# cake 50
# bickit 20
# snack 40
# the total bill is 140

# %%
# NUMBER GAME

# %%
chance = 0
secret_num = 12
print("Guess a secret number")
while chance < 5 :
    
    Guessed_num = (input("enter number : "))
    if type(Guessed_num)==("int"):
        
        if secret_num == Guessed_num:
            print("You Win")
            break
        else:
            print(f"Incorret guess{chance+1} ! enter again.. ")
     
    else :
        print(f"Invalid Output{chance+1}")
    
    chance +=1
    
print("You Fail.......")
# Out:
# Guess a secret number
# Invalid Output1
# Invalid Output2
# Invalid Output3
# Invalid Output4
# Invalid Output5

# %%
type(2)
# Out:
# int
